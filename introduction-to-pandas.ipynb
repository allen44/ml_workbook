# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd

# %%
# 2 main datatypes
series = pd.Series(['BMW', "Toyota", "Honda"])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
# series = 1-dimensional

# %%
colors = pd.Series(["Red", "Blue", "White"])

# %%
colors
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %%
# Dataframe = 2-dimensional
car_data = pd.DataFrame({"Car make": series, "Color": colors})

# %%
car_sales = pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors       Price
# 0           0  Toyota  White         150043      4   $4,000.00
# 1           1   Honda    Red          87899      4   $5,000.00
# 2           2  Toyota   Blue          32549      3   $7,000.00
# 3           3     BMW  Black          11179      5  $22,000.00
# 4           4  Nissan  White         213095      4   $3,500.00
# 5           5  Toyota  Green          99213      4   $4,500.00
# 6           6   Honda   Blue          45698      4   $7,500.00
# 7           7   Honda   Blue          54738      4   $7,000.00
# 8           8  Toyota  White          60000      4   $6,250.00
# 9           9  Nissan  White          31600      4   $9,700.00

# %%
# Exporting a Dataframe
car_sales.to_csv("exported_cars_sales.csv", index=False)

# %%
exported_car_sales = pd.read_csv("exported_cars_sales.csv")

# %%
exported_car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors       Price
# 0           0  Toyota  White         150043      4   $4,000.00
# 1           1   Honda    Red          87899      4   $5,000.00
# 2           2  Toyota   Blue          32549      3   $7,000.00
# 3           3     BMW  Black          11179      5  $22,000.00
# 4           4  Nissan  White         213095      4   $3,500.00
# 5           5  Toyota  Green          99213      4   $4,500.00
# 6           6   Honda   Blue          45698      4   $7,500.00
# 7           7   Honda   Blue          54738      4   $7,000.00
# 8           8  Toyota  White          60000      4   $6,250.00
# 9           9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Describe data

# %%
# Atrribute
car_sales.dtypes

# Function
#car_sales.to_csv()
# Out:
# Unnamed: 0        int64
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Unnamed: 0', 'Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns = car_sales.columns

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
 car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors       Price
# 0           0  Toyota  White         150043      4   $4,000.00
# 1           1   Honda    Red          87899      4   $5,000.00
# 2           2  Toyota   Blue          32549      3   $7,000.00
# 3           3     BMW  Black          11179      5  $22,000.00
# 4           4  Nissan  White         213095      4   $3,500.00
# 5           5  Toyota  Green          99213      4   $4,500.00
# 6           6   Honda   Blue          45698      4   $7,500.00
# 7           7   Honda   Blue          54738      4   $7,000.00
# 8           8  Toyota  White          60000      4   $6,250.00
# 9           9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.describe()
# Describe() works only on numeric columns
# Out:
#        Unnamed: 0  Odometer (KM)      Doors
# count    10.00000      10.000000  10.000000
# mean      4.50000   78601.400000   4.000000
# std       3.02765   61983.471735   0.471405
# min       0.00000   11179.000000   3.000000
# 25%       2.25000   35836.250000   4.000000
# 50%       4.50000   57369.000000   4.000000
# 75%       6.75000   96384.500000   4.000000
# max       9.00000  213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     10 non-null     int64
#  1   Make           10 non-null     object
#  2   Colour         10 non-null     object
#  3   Odometer (KM)  10 non-null     int64
#  4   Doors          10 non-null     int64
#  5   Price          10 non-null     object
# dtypes: int64(3), object(3)
# memory usage: 424.0+ bytes

# %%
car_sales.mean()
# Out:
# Unnamed: 0           4.5
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_prices = pd.Series([3000, 1500, 111250])

# %%
car_prices.mean()
# Out:
# 38583.333333333336

# %%
car_sales.sum()
# Out:
# Unnamed: 0                                                      45
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_prices.sum()
# Out:
# 115750

# %%
car_sales["Doors"].sum()
# Out:
# 40

# %%
len(car_sales)
# Out:
# 10

# %%
car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors       Price
# 0           0  Toyota  White         150043      4   $4,000.00
# 1           1   Honda    Red          87899      4   $5,000.00
# 2           2  Toyota   Blue          32549      3   $7,000.00
# 3           3     BMW  Black          11179      5  $22,000.00
# 4           4  Nissan  White         213095      4   $3,500.00
# 5           5  Toyota  Green          99213      4   $4,500.00
# 6           6   Honda   Blue          45698      4   $7,500.00
# 7           7   Honda   Blue          54738      4   $7,000.00
# 8           8  Toyota  White          60000      4   $6,250.00
# 9           9  Nissan  White          31600      4   $9,700.00

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].mean()
# Out:
# 92302.66666666667

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
#Fill in place = True
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(), inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_dropped = car_sales_missing.dropna()
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing_dropped.to_csv("car_sales_missing_dropped.csv")

# %%
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
# .loc and .iloc
animals = pd.Series(["cat", "dog", "bird", "panda", "snake"], index=[0, 3, 9, 8, 3])

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
# .loc is short for 'location'
animals.loc[3]
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
animals.loc[9]
# Out:
# 'bird'

# %%
car_sales.loc[3]
# Out:
# Unnamed: 0                3
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
#.iloc referes to position
animals.iloc[3]
# Out:
# 'panda'

# %%
# .loc refers to index
#With iloc and loc, we can use slicing
animals.iloc[:3]
# Out:
# 0     cat
# 3     dog
# 9    bird
# dtype: object

# %%
car_sales.loc[:3]
# This is effectively the .head() function, but with the top 4 instead of 5.
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors       Price
# 0           0  Toyota  White         150043      4   $4,000.00
# 1           1   Honda    Red          87899      4   $5,000.00
# 2           2  Toyota   Blue          32549      3   $7,000.00
# 3           3     BMW  Black          11179      5  $22,000.00

# %%
#selecting a column in a dataframe
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales.Make
#using the dot-method, ther must be no space in the column name.
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales[car_sales["Make"] == "Toyota"]
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors      Price
# 0           0  Toyota  White         150043      4  $4,000.00
# 2           2  Toyota   Blue          32549      3  $7,000.00
# 5           5  Toyota  Green          99213      4  $4,500.00
# 8           8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales["Odometer (KM)"] > 100000]
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors      Price
# 0           0  Toyota  White         150043      4  $4,000.00
# 4           4  Nissan  White         213095      4  $3,500.00

# %% [markdown]
# # Viewing and selecting data

# %%
car_sales.head()
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors       Price
# 0           0  Toyota  White         150043      4   $4,000.00
# 1           1   Honda    Red          87899      4   $5,000.00
# 2           2  Toyota   Blue          32549      3   $7,000.00
# 3           3     BMW  Black          11179      5  $22,000.00
# 4           4  Nissan  White         213095      4   $3,500.00

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sales.groupby(["Make"]).mean()
# Out:
#         Unnamed: 0  Odometer (KM)  Doors
# Make
# BMW       3.000000   11179.000000   5.00
# Honda     4.666667   62778.333333   4.00
# Nissan    6.500000  122347.500000   4.00
# Toyota    3.750000   85451.250000   3.75

# %%
car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors       Price
# 0           0  Toyota  White         150043      4   $4,000.00
# 1           1   Honda    Red          87899      4   $5,000.00
# 2           2  Toyota   Blue          32549      3   $7,000.00
# 3           3     BMW  Black          11179      5  $22,000.00
# 4           4  Nissan  White         213095      4   $3,500.00
# 5           5  Toyota  Green          99213      4   $4,500.00
# 6           6   Honda   Blue          45698      4   $7,500.00
# 7           7   Honda   Blue          54738      4   $7,000.00
# 8           8  Toyota  White          60000      4   $6,250.00
# 9           9  Nissan  White          31600      4   $9,700.00

# %%
# %matplotlib inline
import matplotlib as plt

# %%
 car_sales["Odometer (KM)"].plot()

# %%
car_sales["Odometer (KM)"].hist()
# makes a histogram of numberical columns

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '')

# %%
car_sales["Price"]
# Out:
# 0     400000
# 1     500000
# 2     700000
# 3    2200000
# 4     350000
# 5     450000
# 6     750000
# 7     700000
# 8     625000
# 9     970000
# Name: Price, dtype: object

# %% [markdown]
# # Manipulating Data

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors    Price
# 0           0  Toyota  White         150043      4   400000
# 1           1   Honda    Red          87899      4   500000
# 2           2  Toyota   Blue          32549      3   700000
# 3           3     BMW  Black          11179      5  2200000
# 4           4  Nissan  White         213095      4   350000
# 5           5  Toyota  Green          99213      4   450000
# 6           6   Honda   Blue          45698      4   750000
# 7           7   Honda   Blue          54738      4   700000
# 8           8  Toyota  White          60000      4   625000
# 9           9  Nissan  White          31600      4   970000

# %%
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors    Price
# 0           0  toyota  White         150043      4   400000
# 1           1   honda    Red          87899      4   500000
# 2           2  toyota   Blue          32549      3   700000
# 3           3     bmw  Black          11179      5  2200000
# 4           4  nissan  White         213095      4   350000
# 5           5  toyota  Green          99213      4   450000
# 6           6   honda   Blue          45698      4   750000
# 7           7   honda   Blue          54738      4   700000
# 8           8  toyota  White          60000      4   625000
# 9           9  nissan  White          31600      4   970000

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
#Column from Series
seats_column = pd.Series([5, 5, 5, 5, 5])

# New column called seats
car_sales["Seats"] = seats_column

# %%
car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors    Price  Seats
# 0           0  toyota  White         150043      4   400000    5.0
# 1           1   honda    Red          87899      4   500000    5.0
# 2           2  toyota   Blue          32549      3   700000    5.0
# 3           3     bmw  Black          11179      5  2200000    5.0
# 4           4  nissan  White         213095      4   350000    5.0
# 5           5  toyota  Green          99213      4   450000    NaN
# 6           6   honda   Blue          45698      4   750000    NaN
# 7           7   honda   Blue          54738      4   700000    NaN
# 8           8  toyota  White          60000      4   625000    NaN
# 9           9  nissan  White          31600      4   970000    NaN

# %%
car_sales["Seats"].fillna(5, inplace=True)
car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors    Price  Seats
# 0           0  toyota  White         150043      4   400000    5.0
# 1           1   honda    Red          87899      4   500000    5.0
# 2           2  toyota   Blue          32549      3   700000    5.0
# 3           3     bmw  Black          11179      5  2200000    5.0
# 4           4  nissan  White         213095      4   350000    5.0
# 5           5  toyota  Green          99213      4   450000    5.0
# 6           6   honda   Blue          45698      4   750000    5.0
# 7           7   honda   Blue          54738      4   700000    5.0
# 8           8  toyota  White          60000      4   625000    5.0
# 9           9  nissan  White          31600      4   970000    5.0

# %%
# Column from Python list
fuel_economy = [7.5, 9.2, 5.0, 9.6, 8.7, 6.1, 2.3, 4.3, 2.9, 5]
car_sales["Fuel per 100KM"] = fuel_economy
car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors    Price  Seats  \
# 0           0  toyota  White         150043      4   400000    5.0
# 1           1   honda    Red          87899      4   500000    5.0
# 2           2  toyota   Blue          32549      3   700000    5.0
# 3           3     bmw  Black          11179      5  2200000    5.0
# 4           4  nissan  White         213095      4   350000    5.0
# 5           5  toyota  Green          99213      4   450000    5.0
# 6           6   honda   Blue          45698      4   750000    5.0
# 7           7   honda   Blue          54738      4   700000    5.0
# 8           8  toyota  White          60000      4   625000    5.0
# 9           9  nissan  White          31600      4   970000    5.0
#
#    Fuel per 100KM
# 0             7.5
# 1             9.2
# 2             5.0
# 3             9.6
# 4             8.7
# 5             6.1
# 6             2.3
# 7             4.3
# 8             2.9
# 9             5.0

# %%
car_sales["Total fuel used (L)"] = car_sales["Odometer (KM)"]/100 * car_sales["Fuel per 100KM"]
car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors    Price  Seats  \
# 0           0  toyota  White         150043      4   400000    5.0
# 1           1   honda    Red          87899      4   500000    5.0
# 2           2  toyota   Blue          32549      3   700000    5.0
# 3           3     bmw  Black          11179      5  2200000    5.0
# 4           4  nissan  White         213095      4   350000    5.0
# 5           5  toyota  Green          99213      4   450000    5.0
# 6           6   honda   Blue          45698      4   750000    5.0
# 7           7   honda   Blue          54738      4   700000    5.0
# 8           8  toyota  White          60000      4   625000    5.0
# 9           9  nissan  White          31600      4   970000    5.0
#
#    Fuel per 100KM  Total fuel used (L)
# 0             7.5            11253.225
# 1             9.2             8086.708
# 2             5.0             1627.450
# 3             9.6             1073.184
# ...

# %%
# Create a column from a single value (Scalar)

# %%
car_sales["Number of wheels"] = 4
car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors    Price  Seats  \
# 0           0  toyota  White         150043      4   400000    5.0
# 1           1   honda    Red          87899      4   500000    5.0
# 2           2  toyota   Blue          32549      3   700000    5.0
# 3           3     bmw  Black          11179      5  2200000    5.0
# 4           4  nissan  White         213095      4   350000    5.0
# 5           5  toyota  Green          99213      4   450000    5.0
# 6           6   honda   Blue          45698      4   750000    5.0
# 7           7   honda   Blue          54738      4   700000    5.0
# 8           8  toyota  White          60000      4   625000    5.0
# 9           9  nissan  White          31600      4   970000    5.0
#
#    Fuel per 100KM  Total fuel used (L)  Number of wheels
# 0             7.5            11253.225                 4
# 1             9.2             8086.708                 4
# 2             5.0             1627.450                 4
# ...

# %%
car_sales["Passed road safety"] = True
car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors    Price  Seats  \
# 0           0  toyota  White         150043      4   400000    5.0
# 1           1   honda    Red          87899      4   500000    5.0
# 2           2  toyota   Blue          32549      3   700000    5.0
# 3           3     bmw  Black          11179      5  2200000    5.0
# 4           4  nissan  White         213095      4   350000    5.0
# 5           5  toyota  Green          99213      4   450000    5.0
# 6           6   honda   Blue          45698      4   750000    5.0
# 7           7   honda   Blue          54738      4   700000    5.0
# 8           8  toyota  White          60000      4   625000    5.0
# 9           9  nissan  White          31600      4   970000    5.0
#
#    Fuel per 100KM  Total fuel used (L)  Number of wheels  Passed road safety
# 0             7.5            11253.225                 4                True
# ...

# %%
#Shuffle a dataframe by mixing up the indexes
# Use sample

car_sales_shuffled = car_sales.sample(frac=0.5)
car_sales_shuffled
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors   Price  Seats  \
# 4           4  nissan  White         213095      4  350000    5.0
# 1           1   honda    Red          87899      4  500000    5.0
# 7           7   honda   Blue          54738      4  700000    5.0
# 5           5  toyota  Green          99213      4  450000    5.0
# 8           8  toyota  White          60000      4  625000    5.0
#
#    Fuel per 100KM  Total fuel used (L)  Number of wheels  Passed road safety
# 4             8.7            18539.265                 4                True
# 1             9.2             8086.708                 4                True
# 7             4.3             2353.734                 4                True
# 5             6.1             6051.993                 4                True
# 8             2.9             1740.000                 4                True

# %%
# Only select 20% of data
car_sales_shuffled = car_sales.sample(frac=0.2)
car_sales_shuffled
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors   Price  Seats  \
# 2           2  toyota   Blue          32549      3  700000    5.0
# 6           6   honda   Blue          45698      4  750000    5.0
#
#    Fuel per 100KM  Total fuel used (L)  Number of wheels  Passed road safety
# 2             5.0             1627.450                 4                True
# 6             2.3             1051.054                 4                True

# %%
car_sales_shuffled.reset_index(drop=True, inplace=True)
car_sales_shuffled
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors   Price  Seats  \
# 0           2  toyota   Blue          32549      3  700000    5.0
# 1           6   honda   Blue          45698      4  750000    5.0
#
#    Fuel per 100KM  Total fuel used (L)  Number of wheels  Passed road safety
# 0             5.0             1627.450                 4                True
# 1             2.3             1051.054                 4                True

# %%
# Convert Odometer to Miles

car_sales["Odometer (MI)"] = car_sales["Odometer (KM)"].apply(lambda x: x/1.6).round().astype(int)
car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors    Price  Seats  \
# 0           0  toyota  White         150043      4   400000    5.0
# 1           1   honda    Red          87899      4   500000    5.0
# 2           2  toyota   Blue          32549      3   700000    5.0
# 3           3     bmw  Black          11179      5  2200000    5.0
# 4           4  nissan  White         213095      4   350000    5.0
# 5           5  toyota  Green          99213      4   450000    5.0
# 6           6   honda   Blue          45698      4   750000    5.0
# 7           7   honda   Blue          54738      4   700000    5.0
# 8           8  toyota  White          60000      4   625000    5.0
# 9           9  nissan  White          31600      4   970000    5.0
#
#    Fuel per 100KM  Total fuel used (L)  Number of wheels  Passed road safety  \
# 0             7.5            11253.225                 4                True
# ...

# %%
# Try it, run your code
# Search for it
# Try again
# Ask

# %%
car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors    Price  Seats  \
# 0           0  toyota  White         150043      4   400000    5.0
# 1           1   honda    Red          87899      4   500000    5.0
# 2           2  toyota   Blue          32549      3   700000    5.0
# 3           3     bmw  Black          11179      5  2200000    5.0
# 4           4  nissan  White         213095      4   350000    5.0
# 5           5  toyota  Green          99213      4   450000    5.0
# 6           6   honda   Blue          45698      4   750000    5.0
# 7           7   honda   Blue          54738      4   700000    5.0
# 8           8  toyota  White          60000      4   625000    5.0
# 9           9  nissan  White          31600      4   970000    5.0
#
#    Fuel per 100KM  Total fuel used (L)  Number of wheels  Passed road safety  \
# 0             7.5            11253.225                 4                True
# ...

# %%
filter = car_sales['Doors'] > 4

# %%
filter
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: Doors, dtype: bool

# %%
car_sales[filter]
# Out:
#    Unnamed: 0 Make Colour  Odometer (KM)  Doors    Price  Seats  \
# 3           3  bmw  Black          11179      5  2200000    5.0
#
#    Fuel per 100KM  Total fuel used (L)  Number of wheels  Passed road safety  \
# 3             9.6             1073.184                 4                True
#
#    Odometer (MI)
# 3           6987

# %%
car_sales.boxplot(column='Odometer (MI)', by='Make')
