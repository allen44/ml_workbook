# %% [markdown]
# # Introduction to Matplotlib

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
plt.show()

# %%
plt.show()

# %%
plt.plot([1, 2, 3, 4])

# %%
x = [1, 2, 3, 4,]
y= [11, 22, 33, 44]
plt.plot(x, y)

# %%
# 1st method
fig = plt.figure() # creates a figure
ax = fig.add_subplot() # adds some axes
plt.show()

# %%
# 2nd method
fig = plt.figure() # creates a figure
ax = fig.add_axes([1, 1, 1, 1])
ax.plot(x, y) # adds some data
plt.show()

# %%
# 3rd method (recommended)
fig, ax = plt.subplots()
ax.plot(x, [50, 100, 200, 250])
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._subplots.AxesSubplot)

# %% [markdown]
# # Matplotlib example workflow

# %%
# import matplotlib and get it ready for plotting in Jupyter
# %matplotlib inline
import matplotlib.pyplot as plt

# 1. Prepare data
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

# 2. Setup plot
fig, ax = plt.subplots(figsize=(10, 10)) # width, height

# 3. Plot the data
ax.plot(x, y)

# 4. Customize plot
ax.set(title="Simple Plot",
      xlabel="x-axis",
      ylabel="y-axis")

# 5. Save & show (you save the whole figure)
fig.savefig('images\sample-plot.png')

# %% [markdown]
# ## Making figures with numpy arrays
# * Line plot
# * Scatter plot
# * Bar plot
# * Histogram
# * Subplots

# %%
import numpy as np

# %%
# Create some data
x = np.linspace(0, 10, 100) # Returns `num` evenly spaced samples, calculated over the interval [`start`, `stop`].
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
# Plot the data
fig, ax = plt.subplots()
ax.plot(x, x**2)

# %%
# Use same data to make a scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x))

# %%
# Another scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x))

# %%
# Make a plot from dictionary
nut_butter_prices = {"Almod butter": 10,
                    "Peanut butter": 8,
                    "Cashew butter": 12}
fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax.set(title="Allen's Nut Butter Store",
      ylabel="Price ($)")
# Out:
# [Text(0, 0.5, 'Price ($)'), Text(0.5, 1.0, "Allen's Nut Butter Store")]

# %%
fig, ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()))
# Out:
# <BarContainer object of 3 artists>

# %%
# Make some data for histograms and plot it
x = np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(x);

# %%
# Second method
rng = np.random.default_rng()
x = rng.standard_normal(1000)
fig, ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# ### Two options for

# %%
# Subplot option 1, the tuple way
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2,
                                            ncols=2,
                                            figsize=(10, 5))

# Plot to each different axis
ax1.plot(x, x/2);
ax2.scatter(np.random.random(10), np.random.random(10));
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax4.hist(np.random.random(1000));

# %%
# Subplot option 2 , the list index way
fig, ax = plt.subplots(nrows=2,
                       ncols=2,
                       figsize=(10, 5))

# Plot to each different index
ax[0, 0].plot(x, x/2)
ax[0, 1].scatter(np.random.random(10), np.random.random(10))
ax[1, 0].bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax[1, 1].hist(rng.random(1000))
# Out:
# (array([ 96., 101., 102., 100., 100., 104.,  84., 103., 107., 103.]),
#  array([0.00195567, 0.10170946, 0.20146325, 0.30121704, 0.40097083,
#         0.50072462, 0.60047841, 0.7002322 , 0.79998599, 0.89973978,
#         0.99949357]),
#  <a list of 10 Patch objects>)

# %%
# Make a dataframe from csv
import pandas as pd
car_sales = pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors       Price
# 0           0  Toyota  White         150043      4   $4,000.00
# 1           1   Honda    Red          87899      4   $5,000.00
# 2           2  Toyota   Blue          32549      3   $7,000.00
# 3           3     BMW  Black          11179      5  $22,000.00
# 4           4  Nissan  White         213095      4   $3,500.00
# 5           5  Toyota  Green          99213      4   $4,500.00
# 6           6   Honda   Blue          45698      4   $7,500.00
# 7           7   Honda   Blue          54738      4   $7,000.00
# 8           8  Toyota  White          60000      4   $6,250.00
# 9           9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000),
               index=pd.date_range('1/1/2020', periods=1000))
ts = ts.cumsum()
ts.plot()

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '')
#Remove the last two zeros
car_sales["Price"] = car_sales.Price.str[:-2]
#recast price as int
car_sales["Price"] = car_sales["Price"].astype(int)
car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors  Price
# 0           0  Toyota  White         150043      4   4000
# 1           1   Honda    Red          87899      4   5000
# 2           2  Toyota   Blue          32549      3   7000
# 3           3     BMW  Black          11179      5  22000
# 4           4  Nissan  White         213095      4   3500
# 5           5  Toyota  Green          99213      4   4500
# 6           6   Honda   Blue          45698      4   7500
# 7           7   Honda   Blue          54738      4   7000
# 8           8  Toyota  White          60000      4   6250
# 9           9  Nissan  White          31600      4   9700

# %%
car_sales["Sale Date"] = pd.date_range("1/1/2020", periods=len(car_sales))
car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0           0  Toyota  White         150043      4   4000 2020-01-01
# 1           1   Honda    Red          87899      4   5000 2020-01-02
# 2           2  Toyota   Blue          32549      3   7000 2020-01-03
# 3           3     BMW  Black          11179      5  22000 2020-01-04
# 4           4  Nissan  White         213095      4   3500 2020-01-05
# 5           5  Toyota  Green          99213      4   4500 2020-01-06
# 6           6   Honda   Blue          45698      4   7500 2020-01-07
# 7           7   Honda   Blue          54738      4   7000 2020-01-08
# 8           8  Toyota  White          60000      4   6250 2020-01-09
# 9           9  Nissan  White          31600      4   9700 2020-01-10

# %%
car_sales["Total Sales"] = car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors  Price  Sale Date  \
# 0           0  Toyota  White         150043      4   4000 2020-01-01
# 1           1   Honda    Red          87899      4   5000 2020-01-02
# 2           2  Toyota   Blue          32549      3   7000 2020-01-03
# 3           3     BMW  Black          11179      5  22000 2020-01-04
# 4           4  Nissan  White         213095      4   3500 2020-01-05
# 5           5  Toyota  Green          99213      4   4500 2020-01-06
# 6           6   Honda   Blue          45698      4   7500 2020-01-07
# 7           7   Honda   Blue          54738      4   7000 2020-01-08
# 8           8  Toyota  White          60000      4   6250 2020-01-09
# 9           9  Nissan  White          31600      4   9700 2020-01-10
#
#    Total Sales
# 0         4000
# 1         9000
# 2        16000
# 3        38000
# 4        41500
# 5        46000
# 6        53500
# 7        60500
# 8        66750
# 9        76450

# %%
# Let's Plot total sales
car_sales.plot(x="Sale Date", y="Total Sales");

# %%
#Plot scatter plot with price column as numeric
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
# How about a bar graph
x = np.random.rand(10, 4)
x
# Out:
# array([[0.83468182, 0.13376891, 0.05901378, 0.26341586],
#        [0.62941652, 0.10402214, 0.71605365, 0.81763409],
#        [0.89576876, 0.78822592, 0.6239116 , 0.94469185],
#        [0.29978592, 0.23257641, 0.13686275, 0.7136654 ],
#        [0.97032198, 0.94695953, 0.26114514, 0.25827225],
#        [0.12136396, 0.2439929 , 0.4814833 , 0.21033005],
#        [0.13664979, 0.74099266, 0.14277907, 0.303114  ],
#        [0.5560469 , 0.0634855 , 0.38884926, 0.27801382],
#        [0.07321013, 0.21680176, 0.89482197, 0.83100203],
#        [0.41683877, 0.18832285, 0.28308216, 0.21910621]])

# %%
# Turn it into a DataFrame
df = pd.DataFrame(x, columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.834682  0.133769  0.059014  0.263416
# 1  0.629417  0.104022  0.716054  0.817634
# 2  0.895769  0.788226  0.623912  0.944692
# 3  0.299786  0.232576  0.136863  0.713665
# 4  0.970322  0.946960  0.261145  0.258272
# 5  0.121364  0.243993  0.481483  0.210330
# 6  0.136650  0.740993  0.142779  0.303114
# 7  0.556047  0.063485  0.388849  0.278014
# 8  0.073210  0.216802  0.894822  0.831002
# 9  0.416839  0.188323  0.283082  0.219106

# %%
df.plot.bar();

# %%
df.plot(kind="bar");

# %%
car_sales.plot(x="Make", y="Odometer (KM)", kind="bar");

# %%
# How about histograms - great for visualizing distributions

car_sales["Odometer (KM)"].plot.hist();

# %%
car_sales["Odometer (KM)"].plot(kind="hist");

# %%
car_sales["Odometer (KM)"].plot.hist(bins=12);

# %%
# Let's try another data set
heart_disease = pd.read_csv("heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# Create a histogream of age
heart_disease["age"].plot.hist(bins=100);

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
#Plot every columns' histogram
heart_disease.plot.hist(figsize=(10, 30), subplots=True);

# %% [markdown]
# ### Which method should you use? Pyplot vs matplotlib OO-method?
#
# * When plotting something quickly, OK to use the Pyplot method
# * When plotting something more advanced, use the OO method

# %%
# Let's create a subset of the dataframe
over_50 = heart_disease[heart_disease["age"] > 50]
over_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# 4        2   0     2       1
# 5        1   0     1       1
# 6        1   0     2       1
# ..     ...  ..   ...     ...
# 297      1   2     1       0
# 298      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [208 rows x 14 columns]

# %%
#Pyplot method
over_50.plot(kind="scatter",
            x="age",
            y="chol",
            c="target",
            figsize=(10, 6));

# %%
# OO Method - mixed with pyplot method
fig, ax = plt.subplots(figsize=(10, 6))
over_50.plot(kind="scatter",
            x="age",
            y='chol',
            c='target',
            ax=ax);
ax.set_xlim([45, 100]) # Adds some white space to left and right of scatter
# Out:
# (45.0, 100.0)

# %%
## OO Method from scratch
fig, ax = plt.subplots(figsize=(10, 6))

#Plot the data
scatter = ax.scatter(x=over_50["age"],
                    y=over_50["chol"],
                    c=over_50["target"]);

#Customize the plot
ax.set(title="Heart Disease and Cholesterol Levels",
      xlabel="Age",
       ylabel="Cholesterol")

# Add a legend
ax.legend(*scatter.legend_elements(), title="Target");

# Add a horizontal line

ax.axhline(over_50['chol'].mean(),
          linestyle='--');

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
#Subplot with Cholesterol and Maxc Heart Rate on the y-axis, age on x-axis

fig, (ax0, ax1) = plt.subplots(nrows=2,
                               ncols=1,
                               figsize=(10, 10),
                              sharex=True)

# Add data to axes 0
scatter = ax0.scatter(x=over_50['age'],
                     y=over_50['chol'],
                     c=over_50['target'])
# Customize ax0
ax0.set(title="Heart Disease and Cholesterol Levels",
#        xlabel="Age",
       ylabel="Cholesterol")
# Add a legend to ax0
ax0.legend(*scatter.legend_elements(), title="Target")
# Add a horizontal line
ax0.axhline(over_50['chol'].mean(),
            linestyle='--');

# Add data to axes 1
scatter1 = ax1.scatter(x=over_50['age'],
                      y=over_50['thalach'],
                      c=over_50['target'])
# Customize ax1
ax1.set(title="Heart Disease and Max Heart Rate",
       xlabel="Age",
       ylabel="Max Heart Rate")
# Add a legend to ax1
ax1.legend(*scatter1.legend_elements(), title='Target')
# Add a horizontal line
ax1.axhline(over_50['thalach'].mean(),
            linestyle='--');
# Add a title to the figure
fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold")
# Out:
# Text(0.5, 0.98, 'Heart Disease Analysis')

# %%
# See the different styles available
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales["Price"].plot()

# %%
plt.style.use('seaborn-whitegrid')

# %%
car_sales["Price"].plot();

# %%
plt.style.use('seaborn')

# %%
car_sales["Price"].plot()

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter")

# %%
plt.style.use('ggplot')

# %%
car_sales.Price.plot()

# %%
# Create some dummy data
x = np.random.randn(10, 4)
df = pd.DataFrame(x)

# %%
# USe pyplot api because we're doing this quickly
ax = df.plot(kind='bar')
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
# Customize our plot with the set() method
ax = df.plot(kind='bar')
# Add some labels and a title
ax.set(title="Random Number Bar Graph from DataFrame",
      xlabel="Row Number",
      ylabel="Random Number")
# Make the legend visible
ax.legend().set_visible(True)

# %%
#Set the style
plt.style.use('seaborn-whitegrid')

#Subplot with Cholesterol and Maxc Heart Rate on the y-axis, age on x-axis

fig, (ax0, ax1) = plt.subplots(nrows=2,
                               ncols=1,
                               figsize=(10, 10),
                              sharex=True)

# Add data to axes 0
scatter = ax0.scatter(x=over_50['age'],
                     y=over_50['chol'],
                     c=over_50['target'],
                     cmap='plasma') #changes the colors
# Customize ax0
ax0.set(title="Heart Disease and Cholesterol Levels",
#        xlabel="Age",
       ylabel="Cholesterol")
# Add a legend to ax0
ax0.legend(*scatter.legend_elements(), title="Target")
# Add a horizontal line
ax0.axhline(over_50['chol'].mean(),
            linestyle='--');

# Add data to axes 1
scatter1 = ax1.scatter(x=over_50['age'],
                      y=over_50['thalach'],
                      c=over_50['target'],
                      cmap='winter')
# Customize ax1
ax1.set(title="Heart Disease and Max Heart Rate",
       xlabel="Age",
       ylabel="Max Heart Rate")
# Add a legend to ax1
ax1.legend(*scatter1.legend_elements(), title='Target')
# Add a horizontal line
ax1.axhline(over_50['thalach'].mean(),
            linestyle='--');
# Add a title to the figure
fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold");

# %%
# Customizing the x and y axis limitations

#Set the style
plt.style.use('seaborn-whitegrid')

#Subplot with Cholesterol and Maxc Heart Rate on the y-axis, age on x-axis

fig, (ax0, ax1) = plt.subplots(nrows=2,
                               ncols=1,
                               figsize=(10, 10),
                              sharex=True)

# Add data to axes 0
scatter = ax0.scatter(x=over_50['age'],
                     y=over_50['chol'],
                     c=over_50['target'],
                     cmap='winter') #changes the colors
# Customize ax0
ax0.set(title="Heart Disease and Cholesterol Levels",
#        xlabel="Age",
       ylabel="Cholesterol")
ax0.set_xlim([50, 80])
# Add a legend to ax0
ax0.legend(*scatter.legend_elements(), title="Target")
# Add a horizontal line
ax0.axhline(over_50['chol'].mean(),
            linestyle='--');

# Add data to axes 1
scatter1 = ax1.scatter(x=over_50['age'],
                      y=over_50['thalach'],
                      c=over_50['target'],
                      cmap='winter')
# Customize ax1
ax1.set(title="Heart Disease and Max Heart Rate",
       xlabel="Age",
       ylabel="Max Heart Rate")
ax1.set_ylim([60, 200])
# Add a legend to ax1
ax1.legend(*scatter1.legend_elements(), title='Target')
# Add a horizontal line
ax1.axhline(over_50['thalach'].mean(),
            linestyle='--');
# Add a title to the figure
fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold");
